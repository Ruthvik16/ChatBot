# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pickle
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
with open('train_qa.txt', 'rb') as file:
    data = pickle.load(file)
    file.close()
max_story_len = max([len(datas[0]) for datas in data])
max_question_len = max([len(datas[1]) for datas in data])

# %% [markdown]
# # Make Vocabulary

# %%
def load_context(file_path):
    with open(file_path,'rb') as file:
        data = pickle.load(file)
        q = [" ".join(line[0]) for line in data]
    return q

def load_question(file_path):
    with open(file_path,'rb') as file:
        data = pickle.load(file)
        q = [" ".join(line[1]) for line in data]
    return q

def load_answer(file_path):
    with open(file_path,'rb') as file:
        data = pickle.load(file)
        q = ["".join(line[2]) for line in data]
    return q

# %%
train_context = load_context('train_qa.txt')
train_question = load_question('train_qa.txt')
train_answer = load_answer('train_qa.txt')

test_context = load_context('test_qa.txt')
test_question = load_question('test_qa.txt')
test_answer = load_answer('test_qa.txt')

# %%
print("Train : ", len(train_context))
print("Test : ", len(test_context))
# Out:
# Train :  10000
# Test :  1000

# %%
def get_sentence_vectorizer(sentences):
    sentence_vectorizer = tf.keras.layers.TextVectorization(standardize = None)
    sentence_vectorizer.adapt(sentences)
    vocab = sentence_vectorizer.get_vocabulary()
    return sentence_vectorizer, vocab

# %%
vectorizer, vocab = get_sentence_vectorizer(train_context+test_context+train_answer+test_answer+test_context+test_question+[""])
vocab_size = len(vocab)

# %%
vocabulary = {}
for i in range(vocab_size):
    vocabulary[vocab[i].lower()] = i

# %%
vocabulary
# Out:
# {'': 0,
#  '[unk]': 1,
#  'the': 2,
#  '.': 3,
#  'to': 4,
#  'went': 5,
#  'sandra': 6,
#  'mary': 7,
#  'daniel': 8,
#  'john': 9,
#  'there': 10,
#  'journeyed': 11,
#  'travelled': 12,
#  'moved': 13,
#  'back': 14,
#  'bedroom': 15,
#  'kitchen': 16,
#  'office': 17,
#  'hallway': 18,
#  'garden': 19,
#  'bathroom': 20,
#  'milk': 21,
#  'apple': 22,
#  'football': 23,
#  'yes': 24,
#  'no': 25,
#  'got': 26,
#  'up': 27,
#  'picked': 28,
#  'grabbed': 29,
#  'took': 30,
#  'discarded': 31,
#  'dropped': 32,
#  'put': 33,
#  'down': 34,
#  'left': 35,
#  'in': 36,
#  'is': 37,
#  '?': 38}

# %% [markdown]
# # Generating the Dataset

# %%
def generate_dataset(contexts, questions, answers, sentence_vectorizer):
    context_ids = []
    question_ids = []
    answer_ids = []
    
    for i in range(len(contexts)):
        context = contexts[i]
        question = questions[i]
        answer = answers[i]
        veccontext = [vocabulary[word.lower()] for word in context.split(' ')]
        vecquestion = [vocabulary[word.lower()] for word in question.split(' ')]
        vecanswer = np.zeros(vocab_size)
        vecanswer[vocabulary[answer]] = 1
        context_ids.append(veccontext)
        question_ids.append(vecquestion)
        answer_ids.append(vecanswer)

    return (pad_sequences(context_ids, maxlen=max_story_len),pad_sequences(question_ids, maxlen=max_question_len), np.array(answer_ids))

# %%
train_context_vectorised, train_question_vectorised, train_answer_vectorised = generate_dataset(train_context, train_question, train_answer, vectorizer)
test_context_vectorised, test_question_vectorised, test_answer_vectorised  = generate_dataset(test_context, test_question, test_answer, vectorizer)

# %%
val_context_vectorised = train_context_vectorised[9500:]
val_question_vectorised = train_question_vectorised[9500:]
val_answer_vectorised = train_answer_vectorised[9500:]

train_context_vectorised = train_context_vectorised[0:9500]
train_question_vectorised = train_question_vectorised[0:9500]
train_answer_vectorised = train_answer_vectorised[0:9500]

# %% [markdown]
# # Model
# ## Encoders
# ### Input Encoder M

# %%
embedding_dim = 128
input_encoder_m = tf.keras.models.Sequential()
input_encoder_m.add(tf.keras.layers.Embedding(input_dim=vocab_size,output_dim= embedding_dim))
input_encoder_m.add(tf.keras.layers.Dropout(0.3))

# %% [markdown]
# ### Input Encoder C

# %%
input_encoder_c = tf.keras.models.Sequential()
input_encoder_c.add(tf.keras.layers.Embedding(input_dim=vocab_size,output_dim=max_question_len))
input_encoder_c.add(tf.keras.layers.Dropout(0.3))

# %% [markdown]
# ### Question Encoder

# %%
question_encoder = tf.keras.models.Sequential()
question_encoder.add(tf.keras.layers.Embedding(input_dim=vocab_size,
                               output_dim=embedding_dim,
                               input_length=max_question_len))
question_encoder.add(tf.keras.layers.Dropout(0.3))

# %%
input_sequence = tf.keras.layers.Input((max_story_len,))
question = tf.keras.layers.Input((max_question_len,))

# %%
input_encoded_m = input_encoder_m(input_sequence)
input_encoded_c = input_encoder_c(input_sequence)
question_encoded = question_encoder(question)

# %%
match = tf.keras.layers.dot([input_encoded_m, question_encoded], axes=(2, 2))
match = tf.keras.layers.Activation('softmax')(match)

# %%
response = tf.keras.layers.add([match, input_encoded_c])  
response = tf.keras.layers.Permute((2, 1))(response)

# %%
answer = tf.keras.layers.concatenate([response, question_encoded])
answer = tf.keras.layers.LSTM(32)(answer)
answer = tf.keras.layers.Dropout(0.5)(answer)
answer = tf.keras.layers.Dense(vocab_size)(answer) 
answer = tf.keras.layers.Activation('softmax')(answer)

# %%
model = tf.keras.models.Model([input_sequence, question], answer)
model.compile(optimizer=tf.keras.optimizers.legacy.RMSprop(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 156)]                0         []
#
#  input_2 (InputLayer)        [(None, 6)]                  0         []
#
#  sequential (Sequential)     (None, None, 128)            4992      ['input_1[0][0]']
#
#  sequential_2 (Sequential)   (None, 6, 128)               4992      ['input_2[0][0]']
#
#  dot (Dot)                   (None, 156, 6)               0         ['sequential[0][0]',
#                                                                      'sequential_2[0][0]']
#
#  activation (Activation)     (None, 156, 6)               0         ['dot[0][0]']
#
#  sequential_1 (Sequential)   (None, None, 6)              234       ['input_1[0][0]']
#
#  add (Add)                   (None, 156, 6)               0         ['activation[0][0]',
#                                                                      'sequential_1[0][0]']
#
#  permute (Permute)           (None, 6, 156)               0         ['add[0][0]']
#
#  concatenate (Concatenate)   (None, 6, 284)               0         ['permute[0][0]',
#                                                                      'sequential_2[0][0]']
#
#  lstm (LSTM)                 (None, 32)                   40576     ['concatenate[0][0]']
#
#  dropout_3 (Dropout)         (None, 32)                   0         ['lstm[0][0]']
#
#  dense (Dense)               (None, 39)                   1287      ['dropout_3[0][0]']
#
#  activation_1 (Activation)   (None, 39)                   0         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 52081 (203.44 KB)
# Trainable params: 52081 (203.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import math
from tensorflow.keras.callbacks import ReduceLROnPlateau, LearningRateScheduler

initial_learning_rate = 0.01
epochs = 120
decay = initial_learning_rate / epochs

def lr_step_decay(epoch, lr):
    drop_rate = 0.5
    epochs_drop = 20
    return initial_learning_rate * math.pow(drop_rate, math.floor(epoch/epochs_drop))

learning_rate = LearningRateScheduler(lr_step_decay, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.66, patience=5, min_lr=0.0001, verbose=1)  # factor by which the learning rate will be reduced. new_lr = lr * factor

# %%
# train
history = model.fit([train_context_vectorised,train_question_vectorised], train_answer_vectorised,batch_size=256,epochs=250,validation_data=([val_context_vectorised,val_question_vectorised], val_answer_vectorised))  # , callbacks=[reduce_lr]
# Out:
# Epoch 1/250
# 38/38 [==============================] - 7s 158ms/step - loss: 0.9058 - accuracy: 0.4822 - val_loss: 0.7007 - val_accuracy: 0.5200
# Epoch 2/250
# 38/38 [==============================] - 6s 145ms/step - loss: 0.7095 - accuracy: 0.4999 - val_loss: 0.7015 - val_accuracy: 0.5200
# Epoch 3/250
# 38/38 [==============================] - 6s 146ms/step - loss: 0.7011 - accuracy: 0.5039 - val_loss: 0.6988 - val_accuracy: 0.5200
# Epoch 4/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.7002 - accuracy: 0.4951 - val_loss: 0.7153 - val_accuracy: 0.4800
# Epoch 5/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.6977 - accuracy: 0.4998 - val_loss: 0.6986 - val_accuracy: 0.4800
# Epoch 6/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.6965 - accuracy: 0.5024 - val_loss: 0.6951 - val_accuracy: 0.4800
# Epoch 7/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.6964 - accuracy: 0.5028 - val_loss: 0.7004 - val_accuracy: 0.5200
# Epoch 8/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.6793 - accuracy: 0.5327 - val_loss: 0.6605 - val_accuracy: 0.5760
# Epoch 9/250
# 38/38 [==============================] - 5s 142ms/step - loss: 0.6512 - accuracy: 0.5775 - val_loss: 0.6362 - val_accuracy: 0.6560
# Epoch 10/250
# 38/38 [==============================] - 6s 147ms/step - loss: 0.5821 - accuracy: 0.6834 - val_loss: 0.6191 - val_accuracy: 0.6640
# Epoch 11/250
# 38/38 [==============================] - 6s 148ms/step - loss: 0.4596 - accuracy: 0.7928 - val_loss: 0.4117 - val_accuracy: 0.8260
# Epoch 12/250
# 38/38 [==============================] - 6s 148ms/step - loss: 0.3889 - accuracy: 0.8346 - val_loss: 0.4059 - val_accuracy: 0.8460
# Epoch 13/250
# 38/38 [==============================] - 5s 145ms/step - loss: 0.3568 - accuracy: 0.8495 - val_loss: 0.4428 - val_accuracy: 0.8200
# Epoch 14/250
# 38/38 [==============================] - 5s 140ms/step - loss: 0.3387 - accuracy: 0.8568 - val_loss: 0.5044 - val_accuracy: 0.7920
# Epoch 15/250
# 38/38 [==============================] - 5s 126ms/step - loss: 0.3288 - accuracy: 0.8544 - val_loss: 0.3834 - val_accuracy: 0.8340
# Epoch 16/250
# 38/38 [==============================] - 5s 127ms/step - loss: 0.3170 - accuracy: 0.8589 - val_loss: 0.3535 - val_accuracy: 0.8460
# Epoch 17/250
# 38/38 [==============================] - 5s 128ms/step - loss: 0.3182 - accuracy: 0.8581 - val_loss: 0.3420 - val_accuracy: 0.8440
# Epoch 18/250
# 38/38 [==============================] - 5s 129ms/step - loss: 0.3050 - accuracy: 0.8641 - val_loss: 0.3848 - val_accuracy: 0.8460
# Epoch 19/250
# 38/38 [==============================] - 5s 126ms/step - loss: 0.3067 - accuracy: 0.8632 - val_loss: 0.3201 - val_accuracy: 0.8520
# Epoch 20/250
# 38/38 [==============================] - 5s 125ms/step - loss: 0.3022 - accuracy: 0.8654 - val_loss: 0.3609 - val_accuracy: 0.8360
# Epoch 21/250
# 38/38 [==============================] - 5s 127ms/step - loss: 0.2945 - accuracy: 0.8688 - val_loss: 0.4132 - val_accuracy: 0.8280
# Epoch 22/250
# 38/38 [==============================] - 5s 126ms/step - loss: 0.2944 - accuracy: 0.8689 - val_loss: 0.3298 - val_accuracy: 0.8360
# Epoch 23/250
# 38/38 [==============================] - 5s 126ms/step - loss: 0.2971 - accuracy: 0.8669 - val_loss: 0.3734 - val_accuracy: 0.8380
# Epoch 24/250
# 38/38 [==============================] - 5s 125ms/step - loss: 0.2884 - accuracy: 0.8684 - val_loss: 0.3528 - val_accuracy: 0.8360
# Epoch 25/250
# 38/38 [==============================] - 5s 125ms/step - loss: 0.2906 - accuracy: 0.8679 - val_loss: 0.3453 - val_accuracy: 0.8500
# Epoch 26/250
# 38/38 [==============================] - 5s 126ms/step - loss: 0.2863 - accuracy: 0.8742 - val_loss: 0.3443 - val_accuracy: 0.8340
# Epoch 27/250
# 38/38 [==============================] - 5s 124ms/step - loss: 0.2819 - accuracy: 0.8736 - val_loss: 0.3902 - val_accuracy: 0.8060
# Epoch 28/250
# 38/38 [==============================] - 5s 124ms/step - loss: 0.2844 - accuracy: 0.8702 - val_loss: 0.3603 - val_accuracy: 0.8460
# Epoch 29/250
# 38/38 [==============================] - 5s 123ms/step - loss: 0.2760 - accuracy: 0.8773 - val_loss: 0.3819 - val_accuracy: 0.8320
# Epoch 30/250
# 38/38 [==============================] - 5s 122ms/step - loss: 0.2790 - accuracy: 0.8758 - val_loss: 0.4006 - val_accuracy: 0.8300
# Epoch 31/250
# 38/38 [==============================] - 5s 123ms/step - loss: 0.2779 - accuracy: 0.8741 - val_loss: 0.3614 - val_accuracy: 0.8440
# Epoch 32/250
# 38/38 [==============================] - 5s 122ms/step - loss: 0.2734 - accuracy: 0.8773 - val_loss: 0.3473 - val_accuracy: 0.8560
# Epoch 33/250
# 38/38 [==============================] - 170s 5s/step - loss: 0.2714 - accuracy: 0.8807 - val_loss: 0.3473 - val_accuracy: 0.8480
# Epoch 34/250
# 38/38 [==============================] - 5s 122ms/step - loss: 0.2694 - accuracy: 0.8835 - val_loss: 0.4010 - val_accuracy: 0.8280
# Epoch 35/250
# 38/38 [==============================] - 561s 15s/step - loss: 0.2679 - accuracy: 0.8801 - val_loss: 0.3954 - val_accuracy: 0.8320
# Epoch 36/250
# 38/38 [==============================] - 54s 1s/step - loss: 0.2615 - accuracy: 0.8804 - val_loss: 0.3959 - val_accuracy: 0.8340
# Epoch 37/250
# 38/38 [==============================] - 5s 122ms/step - loss: 0.2632 - accuracy: 0.8795 - val_loss: 0.3690 - val_accuracy: 0.8440
# Epoch 38/250
# 38/38 [==============================] - 7s 183ms/step - loss: 0.2628 - accuracy: 0.8819 - val_loss: 0.3363 - val_accuracy: 0.8380
# Epoch 39/250
# 38/38 [==============================] - 27s 731ms/step - loss: 0.2566 - accuracy: 0.8841 - val_loss: 0.4286 - val_accuracy: 0.8340
# Epoch 40/250
# 38/38 [==============================] - 5s 119ms/step - loss: 0.2581 - accuracy: 0.8818 - val_loss: 0.3742 - val_accuracy: 0.8400
# Epoch 41/250
# 38/38 [==============================] - 27s 731ms/step - loss: 0.2532 - accuracy: 0.8885 - val_loss: 0.4519 - val_accuracy: 0.8420
# Epoch 42/250
# 38/38 [==============================] - 268s 7s/step - loss: 0.2560 - accuracy: 0.8857 - val_loss: 0.3734 - val_accuracy: 0.8520
# Epoch 43/250
# 38/38 [==============================] - 5s 124ms/step - loss: 0.2508 - accuracy: 0.8877 - val_loss: 0.4774 - val_accuracy: 0.8460
# Epoch 44/250
# 38/38 [==============================] - 5s 130ms/step - loss: 0.2476 - accuracy: 0.8933 - val_loss: 0.3745 - val_accuracy: 0.8540
# Epoch 45/250
# 38/38 [==============================] - 5s 126ms/step - loss: 0.2487 - accuracy: 0.8903 - val_loss: 0.3588 - val_accuracy: 0.8460
# Epoch 46/250
# 38/38 [==============================] - 35s 952ms/step - loss: 0.2347 - accuracy: 0.8952 - val_loss: 0.3846 - val_accuracy: 0.8600
# Epoch 47/250
# 38/38 [==============================] - 5s 122ms/step - loss: 0.2350 - accuracy: 0.8980 - val_loss: 0.3680 - val_accuracy: 0.8580
# Epoch 48/250
# 38/38 [==============================] - 5s 121ms/step - loss: 0.2258 - accuracy: 0.8997 - val_loss: 0.3821 - val_accuracy: 0.8520
# Epoch 49/250
# 38/38 [==============================] - 5s 120ms/step - loss: 0.2178 - accuracy: 0.9039 - val_loss: 0.3582 - val_accuracy: 0.8560
# Epoch 50/250
# 38/38 [==============================] - 130s 3s/step - loss: 0.2120 - accuracy: 0.9097 - val_loss: 0.3102 - val_accuracy: 0.8840
# Epoch 51/250
# 38/38 [==============================] - 5s 121ms/step - loss: 0.1902 - accuracy: 0.9201 - val_loss: 0.3065 - val_accuracy: 0.8820
# Epoch 52/250
# 38/38 [==============================] - 5s 120ms/step - loss: 0.1866 - accuracy: 0.9212 - val_loss: 0.2808 - val_accuracy: 0.8900
# Epoch 53/250
# 38/38 [==============================] - 17s 453ms/step - loss: 0.1741 - accuracy: 0.9288 - val_loss: 0.2803 - val_accuracy: 0.8960
# Epoch 54/250
# 38/38 [==============================] - 5s 120ms/step - loss: 0.1665 - accuracy: 0.9294 - val_loss: 0.2860 - val_accuracy: 0.9060
# Epoch 55/250
# 38/38 [==============================] - 31s 837ms/step - loss: 0.1592 - accuracy: 0.9346 - val_loss: 0.2699 - val_accuracy: 0.9100
# Epoch 56/250
# 38/38 [==============================] - 4s 113ms/step - loss: 0.1636 - accuracy: 0.9327 - val_loss: 0.2691 - val_accuracy: 0.9120
# Epoch 57/250
# 38/38 [==============================] - 4s 111ms/step - loss: 0.1500 - accuracy: 0.9372 - val_loss: 0.2415 - val_accuracy: 0.9080
# Epoch 58/250
# 38/38 [==============================] - 4s 110ms/step - loss: 0.1505 - accuracy: 0.9348 - val_loss: 0.2309 - val_accuracy: 0.8940
# Epoch 59/250
# 38/38 [==============================] - 8s 215ms/step - loss: 0.1505 - accuracy: 0.9396 - val_loss: 0.2280 - val_accuracy: 0.9000
# Epoch 60/250
# 38/38 [==============================] - 5s 125ms/step - loss: 0.1400 - accuracy: 0.9378 - val_loss: 0.3021 - val_accuracy: 0.9040
# Epoch 61/250
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1404 - accuracy: 0.9434 - val_loss: 0.2727 - val_accuracy: 0.9120
# Epoch 62/250
# 38/38 [==============================] - 5s 120ms/step - loss: 0.1351 - accuracy: 0.9434 - val_loss: 0.2471 - val_accuracy: 0.9120
# Epoch 63/250
# 38/38 [==============================] - 4s 115ms/step - loss: 0.1465 - accuracy: 0.9382 - val_loss: 0.2098 - val_accuracy: 0.9140
# Epoch 64/250
# 38/38 [==============================] - 4s 113ms/step - loss: 0.1323 - accuracy: 0.9462 - val_loss: 0.2303 - val_accuracy: 0.9200
# Epoch 65/250
# 38/38 [==============================] - 5s 120ms/step - loss: 0.1295 - accuracy: 0.9449 - val_loss: 0.2301 - val_accuracy: 0.9040
# Epoch 66/250
# 38/38 [==============================] - 5s 119ms/step - loss: 0.1333 - accuracy: 0.9463 - val_loss: 0.2353 - val_accuracy: 0.9000
# Epoch 67/250
# 38/38 [==============================] - 5s 122ms/step - loss: 0.1286 - accuracy: 0.9464 - val_loss: 0.2528 - val_accuracy: 0.9180
# Epoch 68/250
# 38/38 [==============================] - 5s 122ms/step - loss: 0.1315 - accuracy: 0.9461 - val_loss: 0.2458 - val_accuracy: 0.9200
# Epoch 69/250
# 38/38 [==============================] - 4s 116ms/step - loss: 0.1226 - accuracy: 0.9498 - val_loss: 0.2468 - val_accuracy: 0.9120
# Epoch 70/250
# 38/38 [==============================] - 5s 121ms/step - loss: 0.1261 - accuracy: 0.9465 - val_loss: 0.2338 - val_accuracy: 0.9180
# Epoch 71/250
# 38/38 [==============================] - 4s 116ms/step - loss: 0.1221 - accuracy: 0.9482 - val_loss: 0.2334 - val_accuracy: 0.9120
# Epoch 72/250
# 38/38 [==============================] - 5s 119ms/step - loss: 0.1219 - accuracy: 0.9512 - val_loss: 0.3481 - val_accuracy: 0.8860
# Epoch 73/250
# 38/38 [==============================] - 5s 119ms/step - loss: 0.1163 - accuracy: 0.9532 - val_loss: 0.2329 - val_accuracy: 0.9140
# Epoch 74/250
# 38/38 [==============================] - 4s 116ms/step - loss: 0.1126 - accuracy: 0.9536 - val_loss: 0.2558 - val_accuracy: 0.9160
# Epoch 75/250
# 38/38 [==============================] - 4s 116ms/step - loss: 0.1190 - accuracy: 0.9535 - val_loss: 0.2408 - val_accuracy: 0.9260
# Epoch 76/250
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1198 - accuracy: 0.9522 - val_loss: 0.2648 - val_accuracy: 0.9160
# Epoch 77/250
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1084 - accuracy: 0.9538 - val_loss: 0.2443 - val_accuracy: 0.9180
# Epoch 78/250
# 38/38 [==============================] - 4s 113ms/step - loss: 0.1192 - accuracy: 0.9524 - val_loss: 0.2114 - val_accuracy: 0.9200
# Epoch 79/250
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1084 - accuracy: 0.9557 - val_loss: 0.2681 - val_accuracy: 0.9100
# Epoch 80/250
# 38/38 [==============================] - 4s 113ms/step - loss: 0.1140 - accuracy: 0.9543 - val_loss: 0.3218 - val_accuracy: 0.8940
# Epoch 81/250
# 38/38 [==============================] - 4s 115ms/step - loss: 0.1165 - accuracy: 0.9523 - val_loss: 0.2879 - val_accuracy: 0.9080
# Epoch 82/250
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1069 - accuracy: 0.9571 - val_loss: 0.2590 - val_accuracy: 0.9120
# Epoch 83/250
# 38/38 [==============================] - 4s 116ms/step - loss: 0.1087 - accuracy: 0.9566 - val_loss: 0.3012 - val_accuracy: 0.9220
# Epoch 84/250
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1097 - accuracy: 0.9583 - val_loss: 0.2692 - val_accuracy: 0.9220
# Epoch 85/250
# 38/38 [==============================] - 4s 113ms/step - loss: 0.1041 - accuracy: 0.9578 - val_loss: 0.2793 - val_accuracy: 0.9080
# Epoch 86/250
# 38/38 [==============================] - 4s 114ms/step - loss: 0.1067 - accuracy: 0.9567 - val_loss: 0.2266 - val_accuracy: 0.9160
# Epoch 87/250
# 38/38 [==============================] - 4s 109ms/step - loss: 0.1073 - accuracy: 0.9587 - val_loss: 0.2759 - val_accuracy: 0.9140
# Epoch 88/250
# 38/38 [==============================] - 4s 110ms/step - loss: 0.0988 - accuracy: 0.9604 - val_loss: 0.2346 - val_accuracy: 0.9160
# Epoch 89/250
# 38/38 [==============================] - 4s 110ms/step - loss: 0.1055 - accuracy: 0.9569 - val_loss: 0.2481 - val_accuracy: 0.9140
# Epoch 90/250
# 38/38 [==============================] - 4s 109ms/step - loss: 0.1008 - accuracy: 0.9581 - val_loss: 0.2451 - val_accuracy: 0.9200
# Epoch 91/250
# 38/38 [==============================] - 4s 106ms/step - loss: 0.0983 - accuracy: 0.9604 - val_loss: 0.2529 - val_accuracy: 0.9140
# Epoch 92/250
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0972 - accuracy: 0.9611 - val_loss: 0.2486 - val_accuracy: 0.9340
# Epoch 93/250
# 38/38 [==============================] - 4s 110ms/step - loss: 0.1003 - accuracy: 0.9598 - val_loss: 0.3074 - val_accuracy: 0.9100
# Epoch 94/250
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0922 - accuracy: 0.9617 - val_loss: 0.2997 - val_accuracy: 0.9080
# Epoch 95/250
# 38/38 [==============================] - 4s 107ms/step - loss: 0.1012 - accuracy: 0.9611 - val_loss: 0.2794 - val_accuracy: 0.9080
# Epoch 96/250
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0992 - accuracy: 0.9622 - val_loss: 0.3106 - val_accuracy: 0.9060
# Epoch 97/250
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0933 - accuracy: 0.9637 - val_loss: 0.3360 - val_accuracy: 0.9140
# Epoch 98/250
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0974 - accuracy: 0.9609 - val_loss: 0.2741 - val_accuracy: 0.8980
# Epoch 99/250
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0924 - accuracy: 0.9635 - val_loss: 0.2723 - val_accuracy: 0.9140
# Epoch 100/250
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0899 - accuracy: 0.9642 - val_loss: 0.2618 - val_accuracy: 0.9220
# Epoch 101/250
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0897 - accuracy: 0.9642 - val_loss: 0.3452 - val_accuracy: 0.9180
# Epoch 102/250
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0866 - accuracy: 0.9672 - val_loss: 0.2448 - val_accuracy: 0.9200
# Epoch 103/250
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0817 - accuracy: 0.9656 - val_loss: 0.2758 - val_accuracy: 0.9220
# Epoch 104/250
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0943 - accuracy: 0.9646 - val_loss: 0.3045 - val_accuracy: 0.9260
# Epoch 105/250
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0816 - accuracy: 0.9684 - val_loss: 0.3017 - val_accuracy: 0.9020
# Epoch 106/250
# 38/38 [==============================] - 480s 13s/step - loss: 0.0850 - accuracy: 0.9661 - val_loss: 0.2308 - val_accuracy: 0.9240
# Epoch 107/250
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0836 - accuracy: 0.9674 - val_loss: 0.2186 - val_accuracy: 0.9280
# Epoch 108/250
# 38/38 [==============================] - 12s 311ms/step - loss: 0.0859 - accuracy: 0.9654 - val_loss: 0.2739 - val_accuracy: 0.9180
# Epoch 109/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0815 - accuracy: 0.9694 - val_loss: 0.2486 - val_accuracy: 0.9140
# Epoch 110/250
# 38/38 [==============================] - 60s 2s/step - loss: 0.0777 - accuracy: 0.9696 - val_loss: 0.3980 - val_accuracy: 0.8940
# Epoch 111/250
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0772 - accuracy: 0.9712 - val_loss: 0.2520 - val_accuracy: 0.9340
# Epoch 112/250
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0746 - accuracy: 0.9706 - val_loss: 0.2975 - val_accuracy: 0.9240
# Epoch 113/250
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0772 - accuracy: 0.9711 - val_loss: 0.2187 - val_accuracy: 0.9260
# Epoch 114/250
# 38/38 [==============================] - 4s 105ms/step - loss: 0.0729 - accuracy: 0.9713 - val_loss: 0.2317 - val_accuracy: 0.9160
# Epoch 115/250
# 38/38 [==============================] - 4s 107ms/step - loss: 0.0772 - accuracy: 0.9699 - val_loss: 0.2283 - val_accuracy: 0.9360
# Epoch 116/250
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0726 - accuracy: 0.9735 - val_loss: 0.3002 - val_accuracy: 0.9260
# Epoch 117/250
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0703 - accuracy: 0.9729 - val_loss: 0.2272 - val_accuracy: 0.9240
# Epoch 118/250
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0670 - accuracy: 0.9736 - val_loss: 0.2572 - val_accuracy: 0.9180
# Epoch 119/250
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0712 - accuracy: 0.9724 - val_loss: 0.2608 - val_accuracy: 0.9300
# Epoch 120/250
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0681 - accuracy: 0.9746 - val_loss: 0.2664 - val_accuracy: 0.9200
# Epoch 121/250
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0678 - accuracy: 0.9758 - val_loss: 0.2620 - val_accuracy: 0.9360
# Epoch 122/250
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0627 - accuracy: 0.9784 - val_loss: 0.2719 - val_accuracy: 0.9420
# Epoch 123/250
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0674 - accuracy: 0.9761 - val_loss: 0.2728 - val_accuracy: 0.9260
# Epoch 124/250
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0621 - accuracy: 0.9759 - val_loss: 0.2228 - val_accuracy: 0.9320
# Epoch 125/250
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0692 - accuracy: 0.9755 - val_loss: 0.2715 - val_accuracy: 0.9360
# Epoch 126/250
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0595 - accuracy: 0.9769 - val_loss: 0.2524 - val_accuracy: 0.9320
# Epoch 127/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0670 - accuracy: 0.9765 - val_loss: 0.2414 - val_accuracy: 0.9300
# Epoch 128/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0579 - accuracy: 0.9783 - val_loss: 0.1986 - val_accuracy: 0.9200
# Epoch 129/250
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0636 - accuracy: 0.9767 - val_loss: 0.2127 - val_accuracy: 0.9200
# Epoch 130/250
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0688 - accuracy: 0.9758 - val_loss: 0.2288 - val_accuracy: 0.9280
# Epoch 131/250
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0591 - accuracy: 0.9773 - val_loss: 0.2392 - val_accuracy: 0.9380
# Epoch 132/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0612 - accuracy: 0.9772 - val_loss: 0.2553 - val_accuracy: 0.9260
# Epoch 133/250
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0568 - accuracy: 0.9782 - val_loss: 0.2321 - val_accuracy: 0.9280
# Epoch 134/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0609 - accuracy: 0.9779 - val_loss: 0.2186 - val_accuracy: 0.9340
# Epoch 135/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0513 - accuracy: 0.9801 - val_loss: 0.2342 - val_accuracy: 0.9280
# Epoch 136/250
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0545 - accuracy: 0.9809 - val_loss: 0.1751 - val_accuracy: 0.9420
# Epoch 137/250
# 38/38 [==============================] - 4s 99ms/step - loss: 0.0614 - accuracy: 0.9793 - val_loss: 0.2189 - val_accuracy: 0.9400
# Epoch 138/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0510 - accuracy: 0.9809 - val_loss: 0.2404 - val_accuracy: 0.9240
# Epoch 139/250
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0647 - accuracy: 0.9762 - val_loss: 0.1982 - val_accuracy: 0.9380
# Epoch 140/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0500 - accuracy: 0.9799 - val_loss: 0.2606 - val_accuracy: 0.9220
# Epoch 141/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0507 - accuracy: 0.9804 - val_loss: 0.2041 - val_accuracy: 0.9460
# Epoch 142/250
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0503 - accuracy: 0.9813 - val_loss: 0.2598 - val_accuracy: 0.9260
# Epoch 143/250
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0511 - accuracy: 0.9821 - val_loss: 0.2448 - val_accuracy: 0.9380
# Epoch 144/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0511 - accuracy: 0.9809 - val_loss: 0.2176 - val_accuracy: 0.9480
# Epoch 145/250
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0482 - accuracy: 0.9822 - val_loss: 0.1942 - val_accuracy: 0.9380
# Epoch 146/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0451 - accuracy: 0.9834 - val_loss: 0.2620 - val_accuracy: 0.9320
# Epoch 147/250
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0523 - accuracy: 0.9814 - val_loss: 0.2303 - val_accuracy: 0.9420
# Epoch 148/250
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0426 - accuracy: 0.9847 - val_loss: 0.2575 - val_accuracy: 0.9280
# Epoch 149/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0486 - accuracy: 0.9821 - val_loss: 0.2098 - val_accuracy: 0.9440
# Epoch 150/250
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0504 - accuracy: 0.9817 - val_loss: 0.2081 - val_accuracy: 0.9340
# Epoch 151/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0521 - accuracy: 0.9808 - val_loss: 0.2147 - val_accuracy: 0.9400
# Epoch 152/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0499 - accuracy: 0.9804 - val_loss: 0.2544 - val_accuracy: 0.9180
# Epoch 153/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0525 - accuracy: 0.9820 - val_loss: 0.2570 - val_accuracy: 0.9320
# Epoch 154/250
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0482 - accuracy: 0.9837 - val_loss: 0.2467 - val_accuracy: 0.9320
# Epoch 155/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0434 - accuracy: 0.9848 - val_loss: 0.2252 - val_accuracy: 0.9400
# Epoch 156/250
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0453 - accuracy: 0.9843 - val_loss: 0.2619 - val_accuracy: 0.9280
# Epoch 157/250
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0412 - accuracy: 0.9852 - val_loss: 0.2847 - val_accuracy: 0.9240
# Epoch 158/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0475 - accuracy: 0.9820 - val_loss: 0.1995 - val_accuracy: 0.9280
# Epoch 159/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0433 - accuracy: 0.9840 - val_loss: 0.2402 - val_accuracy: 0.9340
# Epoch 160/250
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0468 - accuracy: 0.9832 - val_loss: 0.2568 - val_accuracy: 0.9440
# Epoch 161/250
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0477 - accuracy: 0.9837 - val_loss: 0.2443 - val_accuracy: 0.9280
# Epoch 162/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0435 - accuracy: 0.9835 - val_loss: 0.2408 - val_accuracy: 0.9280
# Epoch 163/250
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0458 - accuracy: 0.9853 - val_loss: 0.2693 - val_accuracy: 0.9400
# Epoch 164/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0400 - accuracy: 0.9867 - val_loss: 0.2071 - val_accuracy: 0.9260
# Epoch 165/250
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0469 - accuracy: 0.9851 - val_loss: 0.3189 - val_accuracy: 0.9120
# Epoch 166/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0446 - accuracy: 0.9840 - val_loss: 0.2378 - val_accuracy: 0.9280
# Epoch 167/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0481 - accuracy: 0.9829 - val_loss: 0.1736 - val_accuracy: 0.9480
# Epoch 168/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0493 - accuracy: 0.9824 - val_loss: 0.2943 - val_accuracy: 0.9240
# Epoch 169/250
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0477 - accuracy: 0.9832 - val_loss: 0.2371 - val_accuracy: 0.9360
# Epoch 170/250
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0367 - accuracy: 0.9876 - val_loss: 0.2478 - val_accuracy: 0.9340
# Epoch 171/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0401 - accuracy: 0.9857 - val_loss: 0.2253 - val_accuracy: 0.9400
# Epoch 172/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0379 - accuracy: 0.9871 - val_loss: 0.3224 - val_accuracy: 0.9200
# Epoch 173/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0439 - accuracy: 0.9839 - val_loss: 0.1844 - val_accuracy: 0.9300
# Epoch 174/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0351 - accuracy: 0.9879 - val_loss: 0.2000 - val_accuracy: 0.9300
# Epoch 175/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0359 - accuracy: 0.9877 - val_loss: 0.2489 - val_accuracy: 0.9320
# Epoch 176/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.2744 - val_accuracy: 0.9300
# Epoch 177/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0390 - accuracy: 0.9873 - val_loss: 0.2434 - val_accuracy: 0.9340
# Epoch 178/250
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0365 - accuracy: 0.9869 - val_loss: 0.1989 - val_accuracy: 0.9440
# Epoch 179/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0348 - accuracy: 0.9880 - val_loss: 0.1710 - val_accuracy: 0.9480
# Epoch 180/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0368 - accuracy: 0.9877 - val_loss: 0.2493 - val_accuracy: 0.9340
# Epoch 181/250
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0381 - accuracy: 0.9874 - val_loss: 0.2241 - val_accuracy: 0.9460
# Epoch 182/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0341 - accuracy: 0.9882 - val_loss: 0.1929 - val_accuracy: 0.9520
# Epoch 183/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0363 - accuracy: 0.9881 - val_loss: 0.2459 - val_accuracy: 0.9360
# Epoch 184/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0415 - accuracy: 0.9863 - val_loss: 0.2000 - val_accuracy: 0.9500
# Epoch 185/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0415 - accuracy: 0.9873 - val_loss: 0.2430 - val_accuracy: 0.9400
# Epoch 186/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0363 - accuracy: 0.9867 - val_loss: 0.2134 - val_accuracy: 0.9500
# Epoch 187/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0369 - accuracy: 0.9874 - val_loss: 0.2363 - val_accuracy: 0.9480
# Epoch 188/250
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0367 - accuracy: 0.9874 - val_loss: 0.2034 - val_accuracy: 0.9500
# Epoch 189/250
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0462 - accuracy: 0.9849 - val_loss: 0.1818 - val_accuracy: 0.9380
# Epoch 190/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0409 - accuracy: 0.9869 - val_loss: 0.1841 - val_accuracy: 0.9500
# Epoch 191/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 0.2069 - val_accuracy: 0.9400
# Epoch 192/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0401 - accuracy: 0.9866 - val_loss: 0.1608 - val_accuracy: 0.9460
# Epoch 193/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0283 - accuracy: 0.9898 - val_loss: 0.2242 - val_accuracy: 0.9420
# Epoch 194/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0387 - accuracy: 0.9856 - val_loss: 0.1748 - val_accuracy: 0.9560
# Epoch 195/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0327 - accuracy: 0.9877 - val_loss: 0.1995 - val_accuracy: 0.9520
# Epoch 196/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0395 - accuracy: 0.9865 - val_loss: 0.1605 - val_accuracy: 0.9540
# Epoch 197/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0346 - accuracy: 0.9873 - val_loss: 0.2047 - val_accuracy: 0.9300
# Epoch 198/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0327 - accuracy: 0.9885 - val_loss: 0.1890 - val_accuracy: 0.9400
# Epoch 199/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0333 - accuracy: 0.9896 - val_loss: 0.1913 - val_accuracy: 0.9440
# Epoch 200/250
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0292 - accuracy: 0.9892 - val_loss: 0.2025 - val_accuracy: 0.9460
# Epoch 201/250
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0343 - accuracy: 0.9898 - val_loss: 0.2071 - val_accuracy: 0.9420
# Epoch 202/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0318 - accuracy: 0.9897 - val_loss: 0.1820 - val_accuracy: 0.9480
# Epoch 203/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0328 - accuracy: 0.9883 - val_loss: 0.1957 - val_accuracy: 0.9560
# Epoch 204/250
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0368 - accuracy: 0.9888 - val_loss: 0.1752 - val_accuracy: 0.9480
# Epoch 205/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0360 - accuracy: 0.9879 - val_loss: 0.1954 - val_accuracy: 0.9380
# Epoch 206/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0342 - accuracy: 0.9885 - val_loss: 0.2226 - val_accuracy: 0.9360
# Epoch 207/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0365 - accuracy: 0.9899 - val_loss: 0.1587 - val_accuracy: 0.9420
# Epoch 208/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0364 - accuracy: 0.9877 - val_loss: 0.1873 - val_accuracy: 0.9540
# Epoch 209/250
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0321 - accuracy: 0.9898 - val_loss: 0.1957 - val_accuracy: 0.9440
# Epoch 210/250
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0276 - accuracy: 0.9909 - val_loss: 0.1847 - val_accuracy: 0.9500
# Epoch 211/250
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0304 - accuracy: 0.9894 - val_loss: 0.2017 - val_accuracy: 0.9540
# Epoch 212/250
# 38/38 [==============================] - 642s 17s/step - loss: 0.0421 - accuracy: 0.9874 - val_loss: 0.1376 - val_accuracy: 0.9500
# Epoch 213/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 0.2004 - val_accuracy: 0.9520
# Epoch 214/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0405 - accuracy: 0.9897 - val_loss: 0.2321 - val_accuracy: 0.9480
# Epoch 215/250
# 38/38 [==============================] - 77s 2s/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 0.1661 - val_accuracy: 0.9560
# Epoch 216/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0305 - accuracy: 0.9899 - val_loss: 0.1760 - val_accuracy: 0.9540
# Epoch 217/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.1926 - val_accuracy: 0.9560
# Epoch 218/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0355 - accuracy: 0.9887 - val_loss: 0.1667 - val_accuracy: 0.9600
# Epoch 219/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0356 - accuracy: 0.9888 - val_loss: 0.2225 - val_accuracy: 0.9400
# Epoch 220/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0444 - accuracy: 0.9860 - val_loss: 0.1424 - val_accuracy: 0.9520
# Epoch 221/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0331 - accuracy: 0.9887 - val_loss: 0.2037 - val_accuracy: 0.9440
# Epoch 222/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0348 - accuracy: 0.9882 - val_loss: 0.1660 - val_accuracy: 0.9500
# Epoch 223/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0343 - accuracy: 0.9898 - val_loss: 0.1467 - val_accuracy: 0.9580
# Epoch 224/250
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0360 - accuracy: 0.9879 - val_loss: 0.1380 - val_accuracy: 0.9500
# Epoch 225/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.1494 - val_accuracy: 0.9600
# Epoch 226/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0354 - accuracy: 0.9897 - val_loss: 0.1896 - val_accuracy: 0.9500
# Epoch 227/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0341 - accuracy: 0.9867 - val_loss: 0.2578 - val_accuracy: 0.9340
# Epoch 228/250
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0324 - accuracy: 0.9897 - val_loss: 0.1511 - val_accuracy: 0.9500
# Epoch 229/250
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0275 - accuracy: 0.9904 - val_loss: 0.1759 - val_accuracy: 0.9460
# Epoch 230/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0290 - accuracy: 0.9918 - val_loss: 0.1924 - val_accuracy: 0.9500
# Epoch 231/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0359 - accuracy: 0.9892 - val_loss: 0.1476 - val_accuracy: 0.9500
# Epoch 232/250
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0318 - accuracy: 0.9894 - val_loss: 0.1439 - val_accuracy: 0.9520
# Epoch 233/250
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0287 - accuracy: 0.9888 - val_loss: 0.1749 - val_accuracy: 0.9480
# Epoch 234/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0336 - accuracy: 0.9900 - val_loss: 0.2223 - val_accuracy: 0.9520
# Epoch 235/250
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0327 - accuracy: 0.9907 - val_loss: 0.1615 - val_accuracy: 0.9580
# Epoch 236/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0297 - accuracy: 0.9906 - val_loss: 0.1497 - val_accuracy: 0.9540
# Epoch 237/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0309 - accuracy: 0.9913 - val_loss: 0.1426 - val_accuracy: 0.9580
# Epoch 238/250
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0344 - accuracy: 0.9887 - val_loss: 0.1298 - val_accuracy: 0.9540
# Epoch 239/250
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0296 - accuracy: 0.9906 - val_loss: 0.2987 - val_accuracy: 0.9380
# Epoch 240/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0308 - accuracy: 0.9918 - val_loss: 0.1513 - val_accuracy: 0.9560
# Epoch 241/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0257 - accuracy: 0.9922 - val_loss: 0.1376 - val_accuracy: 0.9540
# Epoch 242/250
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0341 - accuracy: 0.9901 - val_loss: 0.1660 - val_accuracy: 0.9540
# Epoch 243/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0307 - accuracy: 0.9904 - val_loss: 0.1440 - val_accuracy: 0.9580
# Epoch 244/250
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 0.1783 - val_accuracy: 0.9500
# Epoch 245/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0326 - accuracy: 0.9898 - val_loss: 0.1387 - val_accuracy: 0.9640
# Epoch 246/250
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.1889 - val_accuracy: 0.9480
# Epoch 247/250
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0226 - accuracy: 0.9920 - val_loss: 0.1702 - val_accuracy: 0.9640
# Epoch 248/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.1491 - val_accuracy: 0.9560
# Epoch 249/250
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0296 - accuracy: 0.9916 - val_loss: 0.1697 - val_accuracy: 0.9500
# Epoch 250/250
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0348 - accuracy: 0.9894 - val_loss: 0.2057 - val_accuracy: 0.9580

# %% [markdown]
# # Testing

# %%
pred_results = model.predict(([test_context_vectorised, test_question_vectorised]))
# Out:
# 32/32 [==============================] - 1s 7ms/step

# %%
#Generate prediction from model
val_max = np.argmax(pred_results[10])
print(pred_results[8])

for key, val in vocabulary.items():
    if val == val_max:
        k = key

print("Predicted answer is: ", k)
print("Probability of certainty was: ", val_max)

test_answer[10]
# Out:
# [3.2695882e-17 3.8785576e-17 3.6220327e-17 4.3115535e-17 4.5350812e-17
#  4.5113388e-17 3.0191722e-17 4.3461985e-17 4.3389759e-17 4.3100408e-17
#  3.7579510e-17 4.9584429e-17 3.6493822e-17 3.7183800e-17 3.3156082e-17
#  5.5727581e-17 3.9489649e-17 3.9396058e-17 3.0380273e-17 3.8085632e-17
#  3.3483245e-17 3.5864225e-17 3.9802101e-17 4.1081535e-17 4.8921032e-07
#  9.9999952e-01 3.7509474e-17 3.9950564e-17 3.9626666e-17 3.1958229e-17
#  3.6998445e-17 3.4924015e-17 4.4902557e-17 3.9289802e-17 3.7664902e-17
#  4.6127585e-17 3.1324082e-17 3.9110956e-17 3.7097092e-17]
# Predicted answer is:  yes
# Probability of certainty was:  24
# 'yes'

# %%
def answer(pred, vocabulary):
    val_max = np.argmax(pred)

    for key, val in vocabulary.items():
        if val == val_max:
            k = key
    return k

# %%
def accuracy(pred_results, vocabulary, test_answer):
    accuracy = 0
    for i in range(len(pred_results)):
        if (str(answer(pred_results[i],vocabulary)) == test_answer[i]):
            accuracy += 1

    accuracy = accuracy/len(pred_results)
    print("Accuracy is : ", accuracy)

# %% [markdown]
# # For a custom test data,

# %%
test_file_name = 'test_qa.txt'

# %%
test_context = load_context(test_file_name)
test_question = load_question(test_file_name)
test_answer = load_answer(test_file_name)
test_context_vectorised, test_question_vectorised, test_answer_vectorised  = generate_dataset(test_context, test_question, test_answer, vectorizer)
pred_results = model.predict(([test_context_vectorised, test_question_vectorised]))
accuracy(pred_results,vocabulary,test_answer)
# Out:
# 32/32 [==============================] - 0s 5ms/step
# Accuracy is :  0.943
